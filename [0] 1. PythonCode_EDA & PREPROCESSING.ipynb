# %% [markdown]
# <a href="https://colab.research.google.com/github/anis-dela/customerchurn/blob/main/%5B0%5D%201.%20PythonCode_EDA%20%26%20PREPROCESSING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PREDICTING CUSTOMER CHURN BASED ON TELCO DATASET

# %% [markdown]
# ### Dataset Yang Digunakan
#
# Dataset yang digunakan diperoleh dari Kaggle yang berisikan data karyawan yang meninggalkan layanan perusahaan (Churn) dari perusahaan telekomunikasi ABC.
#
# Data tersebut dapat dilihat pada link berikut:
# [TELCO DATASET](https://www.kaggle.com/blastchar/telco-customer-churn)

# %% [markdown]
# ### Data Columns
# - CustomerID : menunjukkan ID dari customer
# - gender     : menunjukkan jenis kelamin customer (Male/Female)
# - SeniorCitizen : menunjukkan apakah customer merupakan senior citizen atau bukan (1/0)
# - Partner : menunjukkan apakah customer punya partner atau tidak (1/0)
# - Dependents : menunjukkan apakah customer punya tanggungan atau tidak (1/0)
# - tenure : jumlah bulan customer menjadi pelanggan telco (numerik)
# - PhoneService : apakah customer punya layanan telepon atau tidak (Yes/No)
# - MultipleLines : apakah customer punya multiple lines atau tidak (Yes/No/No phone service)
# - InternetService : menunjukkan provider layanan internet dari customer (DSL/Fiber Optic/No)
# - Online Security : menunjukkan apakah customer memiliki keamanan online atau tidak (Yes/No/No Internet Service)
# - Online Backup : menunjukkan apakah customer memiliki online backup atau tidak (Yes/No/No Internet Service)
# - Device Protection : menunjukkan apakah customer memiliki device protection atau tidak (Yes/No/No Internet Service)
# - Tech Support : menunjukkan apakah customer punya tech support atau tidak (Yes/No/No Internet Service)
# - Payment Method	: The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# - Contract		: The contract term of the customer (Month-to-month, One year, Two year)
# - Tenure			: Number of months the customer has stayed with the company

# %%
#Import Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')

# %%
#Import data
data = pd.read_csv(r'telco_customer.csv')

# %% [markdown]
# ### DATA UNDERSTANDING

# %%
# Melihat Total Baris dan Kolom dari data
data.shape
# Out:
# (7043, 21)

# %%
# Melihat informasi tipe data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Melihat Keseluruhan data
pd.set_option('display.max_columns', 80)
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#Mengubah type TotalCharges menjadi float
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors = 'coerce')

# %% [markdown]
# Setelah tipe data diubah, kemudian dilihat lagi tipe data untuk memastikan bahwa tipe datanya sudah benar

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Selanjutnya dilakukan pengecekan missing value dan data duplikat setelah tipe data diubah

# %%
# Melakukan pengecekan terhadap missing value

data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Melakukan pengecekan duplikasi data

data.duplicated().any()
# Out:
# False

# %%
#Melihat ketika kolom Total Charges berisikan NaN

data[data['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %% [markdown]
# Dataframe di atas menunjukkan data dengan kolom yang berisikan NaN. Setelah ini dilakukan pengecekan data dengan tenure 0, hal ini dikarenakan kami memiliki asumsi bahwa data dengan tenure 0 menghasilkan nilai TotalCharges NaN.

# %%
#Mengecek data dengan tenure = 0
data[data['tenure'] == 0]
#Data dengan tenure = 0 akan menghasilkan totalcharges NaN
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %% [markdown]
# Disini kami melakukan pengecekan terhadap data dengan tenure 0, dimana data dengan tenure 0 akan menghasilkan nilai NaN di TotalCharges. Sehingga kami akan melakukan imputasi untuk TotalCharges dengan tenure 0 dengan nilai 0. Hal ini dikarenakan TotalCharges merupakan perkalian antara tenure dengan MonthlyCharges. Dan ketika tenure 0, dapat dikatakan masih belum ada charges yang dibebankan kepada customer.

# %%
#Karena tenure = 0 menghasilkan totalcharges = NaN, Kolom TotalCharges dengan hasil NaN akan diimputasi dengan nilai 0
data['TotalCharges'] = data['TotalCharges'].fillna(0)

# %%
# Melihat kembali data dengan tenure 0

data[data['tenure'] == 0]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
# Melakukan pengecekan ulang untuk missing value

data.isnull().sum()
#sudah tidak ada data yang missing
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Melakukan pengecekan ulang untuk tipe data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
# Membuat fungsi untuk memisahkan data numerikal dan data kategorikal
def split_columns(data):
    kategorikal = data.select_dtypes(include=['object','category']).columns.tolist()
    numerikal = data.select_dtypes(include=['int32','int64','float64']).columns.tolist()
    return kategorikal,numerikal

# %%
kategori, numeric = split_columns(data)

# %%
kategori.pop()
# Out:
# 'Churn'

# %%
numeric
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
kategori
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
#Menghapus kolom CustomerID

kategori.remove('customerID')

# %%
# Frequency distribution for categoric column
fig, axs = plt.subplots(5, 3, sharex=False, sharey=True, figsize=(30,30))

count_row = 0
count_columns = 0
for column in kategori:
    Bar_Plot = sns.countplot(x=column,hue='Churn',
                             data=data,
                             ax = axs[count_row][count_columns],
                             palette = 'ch:start=.2,rot=-.3').set_title("Frequeny distribution for: " + str(column))

    count_columns +=1

    if count_columns == 3:
        count_row+=1
        count_columns=0

# %%
# Distribution against Churn
for col in numeric:
    sns.displot(data, x=col, kind='kde', hue='Churn', palette = 'colorblind')
    plt.title('KDE {}'.format(col))

# %%
#Correlation between all Column

data_cor = data.copy()

plt.figure(figsize=(15, 8))
corr = data_cor.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
                 linewidths=.2, cmap="YlGnBu")

# %%
# Correlation

# %% [markdown]
# ### DATA VISUALIZATION

# %% [markdown]
# **1. Bagaimana distribusi frekuensi customer yang churn dan yang tidak churn?**

# %%
sns.set_theme(style = 'white')
sns.countplot(data['Churn'], palette = 'ch:start=.2,rot=-.3')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# **2. Apakah gender memengaruhi customer yang churn**

# %%
sns.countplot(x ='gender', hue = 'Churn', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x ='Churn', hue = 'gender', data=data)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# **3. Apakah total charges memengaruhi customer yang churn?**

# %%
data['TotalCharges'] = data['TotalCharges'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
sns.swarmplot(x ='Churn', y = 'TotalCharges', data=data)
#kasih alasan
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# **4. Berapa korelasi dari masing-masing variabel numerik?**

# %%
numerik = pd.DataFrame(data, columns = ['tenure', 'MonthlyCharges', 'TotalCharges'])
numerik
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85            29
# 1         34           56.95          1889
# 2          2           53.85           108
# 3         45           42.30          1840
# 4          2           70.70           151
# ...      ...             ...           ...
# 7038      24           84.80          1990
# 7039      72          103.20          7362
# 7040      11           29.60           346
# 7041       4           74.40           306
# 7042      66          105.65          6844
#
# [7043 rows x 3 columns]

# %%
korelasi = numerik.corr()
#korelasinya apa? kenapa pilihnya pearson?

# %%
plt.figure(figsize = (10,10))
kor = sns.heatmap(korelasi,
    annot = True,
    cmap = 'YlGnBu',
    square = True)

kor.set_xticklabels(
    kor.get_xticklabels(),
    horizontalalignment='right'
);

# %%
data_num = pd.DataFrame(data, columns = ['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn'])
data_num
# Out:
#       tenure  MonthlyCharges  TotalCharges Churn
# 0          1           29.85            29    No
# 1         34           56.95          1889    No
# 2          2           53.85           108   Yes
# 3         45           42.30          1840    No
# 4          2           70.70           151   Yes
# ...      ...             ...           ...   ...
# 7038      24           84.80          1990    No
# 7039      72          103.20          7362    No
# 7040      11           29.60           346    No
# 7041       4           74.40           306   Yes
# 7042      66          105.65          6844    No
#
# [7043 rows x 4 columns]

# %%
corr = data_num.apply(lambda x: pd.factorize(x)[0]).corr()
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
                 linewidths=.2, cmap="YlGnBu", annot = True)

# %% [markdown]
# **5. Bagaimana korelasi Antara Variabel Kategorik dengan Churn?**

# %%
data_kat = data.copy()
data_kat.drop(['tenure', 'MonthlyCharges', 'TotalCharges', 'customerID'], axis = 1, inplace = True)
data_kat
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female              0     Yes         No           No  No phone service
# 1       Male              0      No         No          Yes                No
# 2       Male              0      No         No          Yes                No
# 3       Male              0      No         No           No  No phone service
# 4     Female              0      No         No          Yes                No
# ...      ...            ...     ...        ...          ...               ...
# 7038    Male              0     Yes        Yes          Yes               Yes
# 7039  Female              0     Yes        Yes          Yes               Yes
# 7040  Female              0     Yes        Yes           No  No phone service
# 7041    Male              1     Yes         No          Yes               Yes
# 7042    Male              0      No         No          Yes                No
#
# ...

# %%
import math
import scipy.stats as ss
from collections import Counter

def conditional_entropy(x,y):
    # entropy of x given y
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy

def theil_u(x,y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x

# %%
# Correlation Between Churn and Categorical Variables

theilu = pd.DataFrame(index=['Churn'],columns=data_kat.columns)
columns = data_kat.columns
for j in range(0,len(columns)):
    u = theil_u(data_kat['Churn'].tolist(),data_kat[columns[j]].tolist())
    theilu.loc[:,columns[j]] = u
theilu.fillna(value=np.nan,inplace=True)
plt.figure(figsize=(20,1))
sns.heatmap(theilu,annot=True,fmt='.2f', cmap = 'YlGnBu')
plt.show()

# %% [markdown]
# **5. Bagaimanakah distribusi frekuensi dari variabel numerik di data?**

# %% [markdown]
# **bikin buat yg kategorik**

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,20))

for i, feature in enumerate(numerik,1):
    plt.subplot(5, 3, i)
    sns.distplot(data[feature])

    plt.title('Distribusi dari Variabel {}'.format(feature), size=20, y=1)

# %%
# Distribution against Churn
for col in numeric:
    sns.displot(data, x=col, kind='kde', hue='Churn', palette = 'colorblind')
    plt.title('KDE {}'.format(col))

# %%
sns.distplot(data[data['Churn'] == 'Yes']['tenure'], color = 'Blue')
sns.distplot(data[data['Churn'] == 'No']['tenure'], color = 'Yellow')
sns.set_style("white")
plt.legend(labels = ['Yes', 'No'])

# %%
sns.distplot(data[data['Churn'] == 'Yes']['MonthlyCharges'], color = 'Blue')
sns.distplot(data[data['Churn'] == 'No']['MonthlyCharges'], color = 'Yellow')
sns.set_style("whitegrid")
plt.legend(labels = ['Yes', 'No'])

# %%
sns.distplot(data[data['Churn'] == 'Yes']['TotalCharges'], color = 'Blue')
sns.distplot(data[data['Churn'] == 'No']['TotalCharges'], color = 'Yellow')
sns.set_style("whitegrid")
plt.legend(labels = ['Yes', 'No'])

# %% [markdown]
# **6. Apakah kontrak memengaruhi customer yang churn?**

# %%
sns.countplot(x ='Contract', hue = 'Churn', data=data)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot(x ='Churn', hue = 'Contract', data=data)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# **7. Apakah variabel-variabel kategorik ini memengaruhi customer yang churn**

# %% [markdown]
# **8. Apakah ada outlier?**

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,20))

for i, feature in enumerate(numerik,1):
    plt.subplot(5, 3, i)
    sns.boxplot(data[feature], color = 'LightGreen')
    sns.set_style("white")

    plt.title('Distribusi dari Variabel {}'.format(feature), size=20, y=1)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.style.use('seaborn')

#1 Churn dengan Senior Citizen
plt.subplot(3,2,1)
sns.countplot(x ='Churn', hue = 'SeniorCitizen', data = data)
plt.title('Churn & Senior Citizen')

#1
#Churn dengan partner
plt.subplot(3,2,2)
sns.countplot(x ='Churn', hue = 'Partner', data = data)
plt.title('Churn & Partner')

#3
#Churn dengan Dependents
plt.subplot(3,2,3)
sns.countplot(x ='Churn', hue = 'Dependents', data = data)
plt.title('Churn & Dependents')

#4
#Churn dengan Phone Service
plt.subplot(3,2,4)
sns.countplot(x ='Churn', hue = 'PhoneService', data = data)
plt.title('Churn & Phone Service')


#5
#Churn dengan Multiple Lines
plt.subplot(3,2,5)
sns.countplot(x ='Churn', hue = 'MultipleLines', data = data)
plt.title('Churn & Multiple Lines')

plt.tight_layout()

# %% [markdown]
# **Kalo udah di EDA nanti bikin encoding dan SMOTEnya!!**
# **sebelum smote juga dipake buat comparation**

# %% [markdown]
# ### Encoding

# %% [markdown]
# Kombinasi encoding :
# 1. Pakai Label Encoding untuk semua kolom kategorik
# 2. Pakai One Hot Encoding untuk semua kolom kategorik
# 3. Untuk kategorik dengan 2/3 unique value menggunakan label encoding, sisanya pakai one hot encoding
# 4. Untuk kategorik dengan nilai 2 unique value hanya saja yang menggunakan label encoding, sisanya pakai one hot encoding

# %%
data_1 = data.copy()
data_2 = data.copy()
data_3 = data.copy()
data_4 = data.copy()

# %%
# Import package for encoding
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### 1. Label Encoding untuk semua kolom kategorik

# %%
LE = LabelEncoder()

# %%
kategori_1, numeric_1 = split_columns(data_1)

# %%
for kolom in kategori_1:
    data_1[kolom] = LE.fit_transform(data_1[kolom])

# %%
data_1
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              1                0               0
# ...

# %% [markdown]
# #### 2. One Hot Encoding untuk semua kolom kategorik

# %%
kategori_2, numeric_2 = split_columns(data_2)

# %%
kategori_2.pop()
# Out:
# 'Churn'

# %%
data_2['Churn'] = LE.fit_transform(data_2['Churn'])

# %%
data_2 = pd.get_dummies(data_2, columns=kategori_2)

# %%
data_2
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0                 0       1           29.85            29      0
# 1                 0      34           56.95          1889      0
# 2                 0       2           53.85           108      1
# 3                 0      45           42.30          1840      0
# 4                 0       2           70.70           151      1
# ...             ...     ...             ...           ...    ...
# 7038              0      24           84.80          1990      0
# 7039              0      72          103.20          7362      0
# 7040              0      11           29.60           346      0
# 7041              1       4           74.40           306      1
# 7042              0      66          105.65          6844      0
#
#       customerID_0002-ORFBO  customerID_0003-MKNFE  customerID_0004-TLHLJ  \
# 0                         0                      0                      0
# ...

# %% [markdown]
# #### 3. Untuk kategorik dengan 2 /3 unique value menggunakan label encoding, sisanya pakai one hot encoding

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Separate column 2/3 unique value and more than 3 unique value

less = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'PaperlessBilling', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'Churn']
much = ['PaymentMethod']

# %%
data['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
LE_3 = LabelEncoder()

# %%
for kolom in less:
    data_3[kolom] = LE.fit_transform(data_3[kolom])

# %%
data_3 = pd.get_dummies(data_3, columns=much)

# %%
data_3
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              1                0               0
# ...

# %% [markdown]
# #### 4. Untuk kategorik dengan nilai 2 unique value hanya saja yang menggunakan label encoding, sisanya pakai one hot encoding

# %%
# Separate two unique value and more than two unique value

less4 = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']
much4  = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod']

# %%
LE_4 = LabelEncoder()

# %%
for kolom in less4:
    data_4[kolom] = LE.fit_transform(data_4[kolom])

# %%
data_4 = pd.get_dummies(data_4, columns=much4)

# %%
data_4
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  Churn  \
# ...

# %%
data_1.to_csv('data_model'+str(1)+'.csv', index=False)
data_2.to_csv('data_model'+str(2)+'.csv', index=False)
data_3.to_csv('data_model'+str(3)+'.csv', index=False)
data_4.to_csv('data_model'+str(4)+'.csv', index=False)

# %% [markdown]
# ### Model for Classification with Feature without SMOTE
# - SVM (Anis)
# - Logistic (Anis)
# - KNN (Anis)
# - Random Forest (Crist)
# - Decission Tree (Crist)
# - XGBoost (Crist)
